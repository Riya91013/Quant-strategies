0.013215    0.172893
# 2010-01-06    7.534643    7.656429 -1.590632 -0.121786   -1.590632
# 2010-01-07    7.520714    7.534643 -0.184871 -0.013929   -0.184871
# ...                ...         ...       ...       ...         ...
# 2020-12-24  131.970001  130.960007  0.771224  1.009995    0.771224
# 2020-12-28  136.690002  131.970001  3.576571  4.720001    3.576571
# 2020-12-29  134.869995  136.690002 -1.331485 -1.820007   -1.331485
# 2020-12-30  133.720001  134.869995 -0.852668 -1.149994   -0.852668
# 2020-12-31  132.690002  133.720001 -0.770265 -1.029999   -0.770265
#
# [2770 rows x 5 columns]

# %%
del aapl["Diff2"]

# %%
del aapl["% change 2"]

# %%
aapl
# Out:
#                   AAPL        lag1  % change
# Date
# 2009-12-31    7.526071         NaN       NaN
# 2010-01-04    7.643214    7.526071  1.556498
# 2010-01-05    7.656429    7.643214  0.172893
# 2010-01-06    7.534643    7.656429 -1.590632
# 2010-01-07    7.520714    7.534643 -0.184871
# ...                ...         ...       ...
# 2020-12-24  131.970001  130.960007  0.771224
# 2020-12-28  136.690002  131.970001  3.576571
# 2020-12-29  134.869995  136.690002 -1.331485
# 2020-12-30  133.720001  134.869995 -0.852668
# 2020-12-31  132.690002  133.720001 -0.770265
#
# [2770 rows x 3 columns]

# %%
aapl.rename(columns = {'% change':'change'}, inplace = True)

# %%
aapl
# Out:
#                   AAPL        lag1    change
# Date
# 2009-12-31    7.526071         NaN       NaN
# 2010-01-04    7.643214    7.526071  1.556498
# 2010-01-05    7.656429    7.643214  0.172893
# 2010-01-06    7.534643    7.656429 -1.590632
# 2010-01-07    7.520714    7.534643 -0.184871
# ...                ...         ...       ...
# 2020-12-24  131.970001  130.960007  0.771224
# 2020-12-28  136.690002  131.970001  3.576571
# 2020-12-29  134.869995  136.690002 -1.331485
# 2020-12-30  133.720001  134.869995 -0.852668
# 2020-12-31  132.690002  133.720001 -0.770265
#
# [2770 rows x 3 columns]

# %%
# resampling
# aapl.AAPL.resample("M").last()

# %%
# aapl.AAPL.resample("BM").last().pct_change(periods = 1).mul(100)

# %%
ret = aapl.pct_change().dropna()

# %%
ret
# Out:
#                 AAPL      lag1     change
# Date
# 2010-01-05  0.001729  0.015565  -0.888922
# 2010-01-06 -0.015906  0.001729 -10.200093
# 2010-01-07 -0.001849 -0.015906  -0.883775
# 2010-01-08  0.006648 -0.001849  -4.596201
# 2010-01-11 -0.008821  0.006648  -2.326871
# ...              ...       ...        ...
# 2020-12-24  0.007712 -0.006976  -2.105535
# 2020-12-28  0.035766  0.007712   3.637528
# 2020-12-29 -0.013315  0.035766  -1.372280
# 2020-12-30 -0.008527 -0.013315  -0.359611
# 2020-12-31 -0.007703 -0.008527  -0.096641
#
# [2768 rows x 3 columns]

# %%
del aapl["change"]

# %%
aapl
# Out:
#                   AAPL        lag1
# Date
# 2009-12-31    7.526071         NaN
# 2010-01-04    7.643214    7.526071
# 2010-01-05    7.656429    7.643214
# 2010-01-06    7.534643    7.656429
# 2010-01-07    7.520714    7.534643
# ...                ...         ...
# 2020-12-24  131.970001  130.960007
# 2020-12-28  136.690002  131.970001
# 2020-12-29  134.869995  136.690002
# 2020-12-30  133.720001  134.869995
# 2020-12-31  132.690002  133.720001
#
# [2770 rows x 2 columns]

# %%
del aapl["lag1"]

# %%
aapl
# Out:
#                   AAPL
# Date
# 2009-12-31    7.526071
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# ...                ...
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002
#
# [2770 rows x 1 columns]

# %%
ret = aapl.pct_change().dropna()

# %%
ret.plot(kind = "hist", figsize = (12,8), bins = 100)
plt.show()

# %%
daily_mean_ret = ret.mean()
daily_mean_ret
# Out:
# AAPL    0.001196
# dtype: float64

# %%
var_daily = ret.var()
var_daily
# Out:
# AAPL    0.000318
# dtype: float64

# %%
std_daily= np.sqrt(var_daily)
std_daily
# Out:
# AAPL    0.017841
# dtype: float64

# %%
annual_mean_return = daily_mean_ret*252
annual_mean_return
# Out:
# AAPL    0.301443
# dtype: float64

# %%
annual_var_return = var_daily*252
annual_var_return
# Out:
# AAPL    0.080216
# dtype: float64

# %%
annual_std_return = np.sqrt(annual_var_return)
annual_std_return
# Out:
# AAPL    0.283224
# dtype: float64

# %%
ticker = ["SPY", "AAPL", "KO", "IBM", "DIS", "MSFT"]

# %%
stocks = yf.download(ticker, start = "2010-01-01", end = "2021-01-01")
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
stocks
# Out:
#              Adj Close                                                 \
#                   AAPL         DIS         IBM         KO        MSFT
# Date
# 2009-12-31    6.426000   28.090706   81.321312  19.203468   23.389158
# 2010-01-04    6.526021   27.933914   82.284218  19.216955   23.749823
# 2010-01-05    6.537303   27.864237   81.290237  18.984478   23.757483
# 2010-01-06    6.433318   27.716166   80.762177  18.977741   23.611691
# 2010-01-07    6.421424   27.724874   80.482628  18.930582   23.366129
# ...                ...         ...         ...        ...         ...
# 2020-12-24  130.620895  173.729996  109.422554  50.674915  219.464478
# 2020-12-28  135.292664  178.860001  109.536636  51.357666  221.641861
# 2020-12-29  133.491241  177.300003  108.641525  51.329216  220.843826
# 2020-12-30  132.353012  181.169998  109.115410  51.623173  218.410248
# 2020-12-31  131.333527  181.179993  110.466843  52.002476  219.139313
#
#                              Close                                     ...  \
#                    SPY        AAPL         DIS         IBM         KO  ...
# Date                                                                   ...
# 2009-12-31   87.378471    7.526071   32.250000  125.143402  28.500000  ...
# 2010-01-04   88.860382    7.643214   32.070000  126.625237  28.520000  ...
# 2010-01-05   89.095604    7.656429   31.990000  125.095604  28.174999  ...
# 2010-01-06   89.158333    7.534643   31.820000  124.282982  28.165001  ...
# 2010-01-07   89.534706    7.520714   31.830000  123.852776  28.094999  ...
# ...                ...         ...         ...         ...        ...  ...
# 2020-12-24  359.978088  131.970001  173.729996  119.206497  53.439999  ...
# 2020-12-28  363.070618  136.690002  178.860001  119.330788  54.160000  ...
# 2020-12-29  362.377991  134.869995  177.300003  118.355644  54.130001  ...
# 2020-12-30  362.894989  133.720001  181.169998  118.871895  54.439999  ...
# 2020-12-31  364.738800  132.690002  181.179993  120.344170  54.840000  ...
#
#                   Open                                        Volume  \
#                    IBM         KO        MSFT         SPY       AAPL
# Date
# 2009-12-31  126.586998  28.790001   30.980000  112.769997  352410800
# 2010-01-04  125.411087  28.580000   30.620001  112.370003  493729600
# 2010-01-05  125.889099  28.424999   30.850000  113.260002  601904800
# 2010-01-06  124.933075  28.174999   30.879999  113.519997  552160000
# 2010-01-07  124.158699  28.165001   30.629999  113.500000  477131200
# ...                ...        ...         ...         ...        ...
# 2020-12-24  119.502869  53.020000  221.419998  368.079987   54930100
# 2020-12-28  119.598473  53.849998  224.449997  371.739990  124486200
# 2020-12-29  119.837479  54.450001  226.309998  373.809998  121047300
# 2020-12-30  118.355644  54.049999  225.229996  372.339996   96452100
# 2020-12-31  118.757172  54.450001  221.699997  371.779999   99116600
#
#
#                  DIS      IBM        KO      MSFT        SPY
# Date
# 2009-12-31  19651700  4417676  10848800  31929700   90637900
# 2010-01-04  13700400  6438444  13870400  38409100  118944600
# 2010-01-05  10307700  7156104  23172400  49749600  111579900
# 2010-01-06  10709500  5863144  19264600  58182400  116074400
# 2010-01-07   8202100  6109268  13234600  50559700  131091100
# ...              ...      ...       ...       ...        ...
# 2020-12-24   2721000  1842111   3265500  10550600   26457900
# 2020-12-28  13145400  3781499   9020500  17933500   39000400
# 2020-12-29   6875400  3647402   8320600  17403200   53680500
# 2020-12-30  11680400  3535794   8142700  20272300   49455300
# 2020-12-31   7073500  3738822   8495000  20942100   78520700
#
# [2770 rows x 36 columns]

# %%
close = stocks.loc[:,"Close"].copy()

# %%
normclose = close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize = (15,8), fontsize = 12)
plt.legend(fontsize = 12)
plt.show()

# %%
ret = close.pct_change().dropna()

# %%
ret.head()
# Out:
#                 AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-04  0.015565 -0.005581  0.011841  0.000702  0.015420  0.016960
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328

# %%
ret.describe()
# Out:
#               AAPL          DIS          IBM           KO         MSFT  \
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# mean      0.001196     0.000747     0.000086     0.000298     0.000846
# std       0.017841     0.015715     0.014132     0.011086     0.016012
# min      -0.128647    -0.129846    -0.128507    -0.096725    -0.147390
# 25%      -0.007121    -0.006209    -0.006321    -0.004696    -0.006936
# 50%       0.000905     0.000610     0.000289     0.000440     0.000655
# 75%       0.010384     0.007898     0.006759     0.005705     0.008638
# max       0.119808     0.144123     0.113010     0.064796     0.142169
#
#                SPY
# count  2769.000000
# mean      0.000497
# std       0.010911
# min      -0.109424
# 25%      -0.003531
# 50%       0.000637
# 75%       0.005426
# max       0.090603

# %%
summary = ret.describe().T.loc[:,["mean", "std"]]
summary
# Out:
#           mean       std
# AAPL  0.001196  0.017841
# DIS   0.000747  0.015715
# IBM   0.000086  0.014132
# KO    0.000298  0.011086
# MSFT  0.000846  0.016012
# SPY   0.000497  0.010911

# %%
summary["mean"] = summary["mean"]*252
summary["std"] = summary["std"]*np.sqrt(252)
summary
# Out:
#           mean       std
# AAPL  0.301443  0.283224
# DIS   0.188119  0.249466
# IBM   0.021718  0.224333
# KO    0.075128  0.175977
# MSFT  0.213242  0.254177
# SPY   0.125252  0.173210

# %%
summary.plot.scatter(x = "std", y = "mean", figsize = (12,8), s = 50, fontsize = 15)
for i in summary.index:
    plt.annotate(i, xy = (summary.loc[i,"std"] + 0.002, summary.loc[i,"mean"] + 0.002), size = 15)
plt.xlabel("Annual risk(std)", fontsize = 15)
plt.ylabel("Annual return", fontsize = 15)
plt.title("Risk/return", fontsize = 25)
plt.show()

# %% [markdown]
# # Correlation and Covariance

# %%
ret
# Out:
#                 AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-04  0.015565 -0.005581  0.011841  0.000702  0.015420  0.016960
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328
# ...              ...       ...       ...       ...       ...       ...
# 2020-12-24  0.007712  0.001037  0.006376  0.006782  0.007827  0.003890
# 2020-12-28  0.035766  0.029529  0.001043  0.013473  0.009921  0.008591
# 2020-12-29 -0.013315 -0.008722 -0.008172 -0.000554 -0.003601 -0.001908
# 2020-12-30 -0.008527  0.021827  0.004362  0.005727 -0.011019  0.001427
# 2020-12-31 -0.007703  0.000055  0.012385  0.007348  0.003338  0.005081
#
# [2769 rows x 6 columns]

# %%
ret.cov()
# Out:
#           AAPL       DIS       IBM        KO      MSFT       SPY
# AAPL  0.000318  0.000114  0.000110  0.000067  0.000158  0.000128
# DIS   0.000114  0.000247  0.000111  0.000085  0.000121  0.000121
# IBM   0.000110  0.000111  0.000200  0.000079  0.000121  0.000108
# KO    0.000067  0.000085  0.000079  0.000123  0.000076  0.000077
# MSFT  0.000158  0.000121  0.000121  0.000076  0.000256  0.000130
# SPY   0.000128  0.000121  0.000108  0.000077  0.000130  0.000119

# %%
ret.corr()
# Out:
#           AAPL       DIS       IBM        KO      MSFT       SPY
# AAPL  1.000000  0.408336  0.436236  0.339184  0.554168  0.659648
# DIS   0.408336  1.000000  0.497577  0.486494  0.480239  0.706195
# IBM   0.436236  0.497577  1.000000  0.502384  0.533257  0.703418
# KO    0.339184  0.486494  0.502384  1.000000  0.429696  0.639080
# MSFT  0.554168  0.480239  0.533257  0.429696  1.000000  0.744679
# SPY   0.659648  0.706195  0.703418  0.639080  0.744679  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale = 1.4)
sns.heatmap(ret.corr(), cmap= "Reds", annot = True, annot_kws = {"size" : 15}, vmax = 0.6)
plt.show()

# %% [markdown]
# # Simple returns and log returns

# %%
df = pd.DataFrame(index = [2016, 2017, 2018], data = [100,50,95], columns = ["Price"])
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
simplereturns = df.pct_change().dropna()
simplereturns
# Out:
#       Price
# 2017   -0.5
# 2018    0.9

# %%
simplereturns.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
100*1.2*1.2
# Out:
# 144.0

# %%
# mean returns are very misleading

# %%
logreturns = np.log(df/df.shift(1)).dropna()
logreturns
# Out:
#          Price
# 2017 -0.693147
# 2018  0.641854

# %%
logreturns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
100*np.exp(logreturns.mean()*2)
# Out:
# Price    95.0
# dtype: float64

# %%
SPY = yf.download("SPY")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
spy = SPY.Close.to_frame()

# %%
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2022-09-15  390.119995
# 2022-09-16  385.559998
# 2022-09-19  388.549988
# 2022-09-20  384.089996
# 2022-09-21  377.390015
#
# [7466 rows x 1 columns]

# %%
spy.plot(figsize = (12,8), fontsize = 15)
plt.legend(loc = "upper left", fontsize = 15)
plt.show()

# %%
spy_roll = spy.rolling(window = 10)

# %%
spy_roll = spy_roll.mean()

# %%
spy_roll
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2022-09-15  397.297003
# 2022-09-16  396.211002
# 2022-09-19  395.842001
# 2022-09-20  395.175000
# 2022-09-21  393.136002
#
# [7466 rows x 1 columns]

# %%
spy.rolling(window = 10).median()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2022-09-15  395.510010
# 2022-09-16  393.850006
# 2022-09-19  393.850006
# 2022-09-20  393.850006
# 2022-09-21  391.610001
#
# [7466 rows x 1 columns]

# %%
spy.rolling(window = 10).max()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2022-09-15  410.970001
# 2022-09-16  410.970001
# 2022-09-19  410.970001
# 2022-09-20  410.970001
# 2022-09-21  410.970001
#
# [7466 rows x 1 columns]

# %%
spy.rolling(window = 10, min_periods = 5).max().head(15)
# Out:
#                Close
# Date
# 1993-01-29       NaN
# 1993-02-01       NaN
# 1993-02-02       NaN
# 1993-02-03       NaN
# 1993-02-04  45.00000
# 1993-02-05  45.00000
# 1993-02-08  45.00000
# 1993-02-09  45.00000
# 1993-02-10  45.00000
# 1993-02-11  45.00000
# 1993-02-12  45.00000
# 1993-02-16  45.00000
# 1993-02-17  45.00000
# 1993-02-18  45.00000
# 1993-02-19  44.96875

# %%
spy["SMA50"] = spy.rolling(window = 50, min_periods = 50).mean()

# %%
# spy.head(60)

# %%
spy.plot(figsize = (12,8), fontsize = 15)
plt.legend(loc = "upper left", fontsize = 15)
plt.show()

# %%
spy["SMA200"] = spy.Close.rolling(window = 200, min_periods = 200).mean()
spy.plot(figsize = (12,8), fontsize = 15)
plt.legend(loc = "upper left", fontsize = 15)
plt.show()

# %%
spy["EMA200"] = spy.Close.ewm(span = 200, min_periods = 200).mean()

# %%
spy
# Out:
#                  Close       SMA50      SMA200      EMA200
# Date
# 1993-01-29   43.937500         NaN         NaN         NaN
# 1993-02-01   44.250000         NaN         NaN         NaN
# 1993-02-02   44.343750         NaN         NaN         NaN
# 1993-02-03   44.812500         NaN         NaN         NaN
# 1993-02-04   45.000000         NaN         NaN         NaN
# ...                ...         ...         ...         ...
# 2022-09-15  390.119995  403.475602  425.193251  415.320246
# 2022-09-16  385.559998  403.407002  424.843251  415.024124
# 2022-09-19  388.549988  403.404601  424.533501  414.760700
# 2022-09-20  384.089996  403.401801  424.166951  414.455519
# 2022-09-21  377.390015  403.333002  423.786801  414.086708
#
# [7466 rows x 4 columns]

# %%
spy.plot(figsize = (12,8), fontsize = 15)
plt.legend(loc = "upper left", fontsize = 15)
plt.show()

# %%
spy["Day"] = spy.index.day_name()

# %%
spy["Quarter"] = spy.index.quarter

# %%
SPY = yf.download("SPY")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# spy = spy.to_frame()

# %%
close = SPY.loc[:,"Close"].copy().dropna()

# %%
close = close.to_frame()

# %%
close
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2022-09-15  390.119995
# 2022-09-16  385.559998
# 2022-09-19  388.549988
# 2022-09-20  384.089996
# 2022-09-21  377.390015
#
# [7466 rows x 1 columns]

# %%
all_days = pd.date_range(start = "2010-12-31", end = "2020-01-01", freq = "D")
all_days
# Out:
# DatetimeIndex(['2010-12-31', '2011-01-01', '2011-01-02', '2011-01-03',
#                '2011-01-04', '2011-01-05', '2011-01-06', '2011-01-07',
#                '2011-01-08', '2011-01-09',
#                ...
#                '2019-12-23', '2019-12-24', '2019-12-25', '2019-12-26',
#                '2019-12-27', '2019-12-28', '2019-12-29', '2019-12-30',
#                '2019-12-31', '2020-01-01'],
#               dtype='datetime64[ns]', length=3289, freq='D')

# %%
close = close.reindex(all_days)

# %%
close
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01         NaN
# 2011-01-02         NaN
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2019-12-28         NaN
# 2019-12-29         NaN
# 2019-12-30  321.079987
# 2019-12-31  321.859985
# 2020-01-01         NaN
#
# [3289 rows x 1 columns]

# %%
# forward fill
close.fillna(method = "ffill")
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01  125.750000
# 2011-01-02  125.750000
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2019-12-28  322.859985
# 2019-12-29  322.859985
# 2019-12-30  321.079987
# 2019-12-31  321.859985
# 2020-01-01  321.859985
#
# [3289 rows x 1 columns]

# %%
# backward fill
close.fillna(method = "bfill")
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01  127.050003
# 2011-01-02  127.050003
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2019-12-28  321.079987
# 2019-12-29  321.079987
# 2019-12-30  321.079987
# 2019-12-31  321.859985
# 2020-01-01         NaN
#
# [3289 rows x 1 columns]

# %%
SPY = yf.download("SPY", interval = "1wk")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
SPY
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-25   43.968750   43.968750   43.750000   43.937500   25.334034
# 1993-02-01   43.968750   45.093750   43.968750   44.968750   25.928638
# 1993-02-08   44.968750   45.125000   44.531250   44.593750   25.712420
# 1993-02-15   44.468750   44.468750   42.812500   43.562500   25.117805
# 1993-02-22   43.687500   44.437500   43.468750   44.406250   25.604311
# ...                ...         ...         ...         ...         ...
# 2022-09-05  393.130005  407.510010  388.420013  406.600006  404.936584
# 2022-09-12  408.779999  411.730011  382.109985  385.559998  383.982666
# 2022-09-16         NaN         NaN         NaN         NaN         NaN
# 2022-09-19  382.260010  389.309998  377.380005  377.390015  377.390015
# 2022-09-21  386.109985  389.299988  377.380005  377.390015  377.390015
#
#                  Volume
# Date
# 1993-01-25    1003200.0
# 1993-02-01    2234800.0
# 1993-02-08    1159800.0
# 1993-02-15     998700.0
# 1993-02-22    1024300.0
# ...                 ...
# 2022-09-05  305041400.0
# 2022-09-12  467667000.0
# 2022-09-16          NaN
# 2022-09-19  256837900.0
# 2022-09-21  106746554.0
#
# [1668 rows x 6 columns]

# %% [markdown]
# # Cumulative returns, drawdowns etc.

# %%
apple = yf.download("AAPL")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
apple= apple.Close.to_frame()

# %%
apple
# Out:
#                  Close
# Date
# 1980-12-12    0.128348
# 1980-12-15    0.121652
# 1980-12-16    0.112723
# 1980-12-17    0.115513
# 1980-12-18    0.118862
# ...                ...
# 2022-09-15  152.369995
# 2022-09-16  150.699997
# 2022-09-19  154.479996
# 2022-09-20  156.899994
# 2022-09-21  153.720001
#
# [10533 rows x 1 columns]

# %%
apple["d_returns"] = np.log(apple.div(apple.shift(1)))

# %%
apple.dropna(inplace = True)

# %%
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# 1980-12-19    0.126116   0.059239
# ...                ...        ...
# 2022-09-15  152.369995  -0.019111
# 2022-09-16  150.699997  -0.011021
# 2022-09-19  154.479996   0.024774
# 2022-09-20  156.899994   0.015544
# 2022-09-21  153.720001  -0.020476
#
# [10532 rows x 2 columns]

# %%
apple.d_returns.sum()
# Out:
# 7.088142783157489

# %%
np.exp(apple.d_returns.sum())
# Out:
# 1197.6813797472066

# %%
apple["cumm_returns"] = apple.d_returns.cumsum().apply(np.exp)

# %%
apple
# Out:
#                  Close  d_returns  cumm_returns
# Date
# 1980-12-15    0.121652  -0.053581      0.947829
# 1980-12-16    0.112723  -0.076231      0.878261
# 1980-12-17    0.115513   0.024450      0.899998
# 1980-12-18    0.118862   0.028580      0.926092
# 1980-12-19    0.126116   0.059239      0.982610
# ...                ...        ...           ...
# 2022-09-15  152.369995  -0.019111   1187.163053
# 2022-09-16  150.699997  -0.011021   1174.151567
# 2022-09-19  154.479996   0.024774   1203.602738
# 2022-09-20  156.899994   0.015544   1222.457713
# 2022-09-21  153.720001  -0.020476   1197.681380
#
# [10532 rows x 3 columns]

# %%
apple.cumm_returns.plot(figsize=(12,8), title = "APPLE BUY and HOLD", fontsize = 12)
plt.show()

# %%
apple.d_returns.mean()*252
# Out:
# 0.16959855500908602

# %%
apple.d_returns.std()*np.sqrt(252)
# Out:
# 0.4561680281751479

# %% [markdown]
# # How to calculate drawdowns

# %%
apple["cummmax"] = apple.cumm_returns.cummax()

# %%
apple
# Out:
#                  Close  d_returns  cumm_returns      cummmax
# Date
# 1980-12-15    0.121652  -0.053581      0.947829     0.947829
# 1980-12-16    0.112723  -0.076231      0.878261     0.947829
# 1980-12-17    0.115513   0.024450      0.899998     0.947829
# 1980-12-18    0.118862   0.028580      0.926092     0.947829
# 1980-12-19    0.126116   0.059239      0.982610     0.982610
# ...                ...        ...           ...          ...
# 2022-09-15  152.369995  -0.019111   1187.163053  1418.097708
# 2022-09-16  150.699997  -0.011021   1174.151567  1418.097708
# 2022-09-19  154.479996   0.024774   1203.602738  1418.097708
# 2022-09-20  156.899994   0.015544   1222.457713  1418.097708
# 2022-09-21  153.720001  -0.020476   1197.681380  1418.097708
#
# [10532 rows x 4 columns]

# %%
apple[["cumm_returns", "cummmax"]].plot(figsize=(12,8), title = "APPLE BUY and HOLD + cummax", fontsize = 12)
plt.show()

# %%
apple["drawdown"] = apple["cummmax"] - apple["cumm_returns"]

# %%
apple
# Out:
#                  Close  d_returns  cumm_returns      cummmax    drawdown
# Date
# 1980-12-15    0.121652  -0.053581      0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231      0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450      0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580      0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239      0.982610     0.982610    0.000000
# ...                ...        ...           ...          ...         ...
# 2022-09-15  152.369995  -0.019111   1187.163053  1418.097708  230.934654
# 2022-09-16  150.699997  -0.011021   1174.151567  1418.097708  243.946141
# 2022-09-19  154.479996   0.024774   1203.602738  1418.097708  214.494969
# 2022-09-20  156.899994   0.015544   1222.457713  1418.097708  195.639994
# 2022-09-21  153.720001  -0.020476   1197.681380  1418.097708  220.416328
#
# [10532 rows x 5 columns]

# %%
apple.drawdown.max()
# Out:
# 404.7589352637674

# %%
apple.drawdown.idxmax()
# Out:
# Timestamp('2022-06-16 00:00:00')

# %%
apple.loc[(apple.index<='2022-06-16')]
# Out:
#                  Close  d_returns  cumm_returns      cummmax    drawdown
# Date
# 1980-12-15    0.121652  -0.053581      0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231      0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450      0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580      0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239      0.982610     0.982610    0.000000
# ...                ...        ...           ...          ...         ...
# 2022-06-10  137.130005  -0.039395   1068.423446  1418.097708  349.674261
# 2022-06-13  131.880005  -0.039037   1027.519028  1418.097708  390.578680
# 2022-06-14  132.759995   0.006650   1034.375307  1418.097708  383.722401
# 2022-06-15  135.429993   0.019912   1055.178111  1418.097708  362.919597
# 2022-06-16  130.059998  -0.040459   1013.338772  1418.097708  404.758935
#
# [10466 rows x 5 columns]

# %%
apple["% drawdown"] = (apple["cummmax"] - apple["cumm_returns"])/apple["cummmax"]

# %%
apple
# Out:
#                  Close  d_returns  cumm_returns      cummmax    drawdown  \
# Date
# 1980-12-15    0.121652  -0.053581      0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231      0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450      0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580      0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239      0.982610     0.982610    0.000000
# ...                ...        ...           ...          ...         ...
# 2022-09-15  152.369995  -0.019111   1187.163053  1418.097708  230.934654
# 2022-09-16  150.699997  -0.011021   1174.151567  1418.097708  243.946141
# 2022-09-19  154.479996   0.024774   1203.602738  1418.097708  214.494969
# 2022-09-20  156.899994   0.015544   1222.457713  1418.097708  195.639994
# 2022-09-21  153.720001  -0.020476   1197.681380  1418.097708  220.416328
#
#             % drawdown
# Date
# 1980-12-15    0.000000
# 1980-12-16    0.073398
# 1980-12-17    0.050464
# 1980-12-18    0.022934
# 1980-12-19    0.000000
# ...                ...
# 2022-09-15    0.162848
# 2022-09-16    0.172024
# 2022-09-19    0.151255
# 2022-09-20    0.137959
# 2022-09-21    0.155431
#
# [10532 rows x 6 columns]

# %%
apple["% drawdown"].max()
# Out:
# 0.82216567924191

# %%
apple["% drawdown"].idxmax()
# Out:
# Timestamp('1997-12-23 00:00:00')

# %%
apple.loc[(apple.index=='1997-12-23')]
# Out:
#                Close  d_returns  cumm_returns   cummmax  drawdown  % drawdown
# Date
# 1997-12-23  0.115513   -0.02858      0.899998  5.060882  4.160883    0.822166

# %% [markdown]
# # SMA Strategy

# %%
data = apple.Close.loc[(apple.index>='1991-01-01')]

# %%
data = data.to_frame()

# %%
data
# Out:
#                  Close
# Date
# 1991-01-02    0.388393
# 1991-01-03    0.383929
# 1991-01-04    0.386161
# 1991-01-07    0.386161
# 1991-01-08    0.386161
# ...                ...
# 2022-09-15  152.369995
# 2022-09-16  150.699997
# 2022-09-19  154.479996
# 2022-09-20  156.899994
# 2022-09-21  153.720001
#
# [7992 rows x 1 columns]

# %%
sma_s = 50
sma_l = 100

# %%
data["sma_s"] = data.Close.rolling(sma_s).mean()
data["sma_l"] = data.Close.rolling(sma_l).mean()

# %%
data
# Out:
#                  Close     sma_s     sma_l
# Date
# 1991-01-02    0.388393       NaN       NaN
# 1991-01-03    0.383929       NaN       NaN
# 1991-01-04    0.386161       NaN       NaN
# 1991-01-07    0.386161       NaN       NaN
# 1991-01-08    0.386161       NaN       NaN
# ...                ...       ...       ...
# 2022-09-15  152.369995  159.3880  152.4316
# 2022-09-16  150.699997  159.4750  152.3098
# 2022-09-19  154.479996  159.6238  152.2866
# 2022-09-20  156.899994  159.8644  152.2899
# 2022-09-21  153.720001  160.0216  152.1907
#
# [7992 rows x 3 columns]

# %%
data.plot(figsize = (12,8), title = "AAPLE - SMA{} | SMA{}".format(sma_s, sma_l), fontsize = 12)
plt.show()

# %%
data.loc["2016"].plot(figsize = (12,8), title = "AAPLE - SMA{} | SMA{}".format(sma_s, sma_l), fontsize = 12)
plt.show()

# %%
data.dropna(inplace = True)
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 1991-05-23    0.402902    0.534420    0.513326
# 1991-05-24    0.409598    0.530960    0.513538
# 1991-05-28    0.410714    0.527344    0.513806
# 1991-05-29    0.419643    0.523638    0.514141
# 1991-05-30    0.425223    0.519732    0.514531
# ...                ...         ...         ...
# 2022-09-15  152.369995  159.388000  152.431600
# 2022-09-16  150.699997  159.475000  152.309800
# 2022-09-19  154.479996  159.623800  152.286600
# 2022-09-20  156.899994  159.864400  152.289900
# 2022-09-21  153.720001  160.021600  152.190700
#
# [7893 rows x 3 columns]

# %%
data["position"] = np.where(data["sma_s"] > data["sma_l"], 1, -1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1
# 1991-05-24    0.409598    0.530960    0.513538         1
# 1991-05-28    0.410714    0.527344    0.513806         1
# 1991-05-29    0.419643    0.523638    0.514141         1
# 1991-05-30    0.425223    0.519732    0.514531         1
# ...                ...         ...         ...       ...
# 2022-09-15  152.369995  159.388000  152.431600         1
# 2022-09-16  150.699997  159.475000  152.309800         1
# 2022-09-19  154.479996  159.623800  152.286600         1
# 2022-09-20  156.899994  159.864400  152.289900         1
# 2022-09-21  153.720001  160.021600  152.190700         1
#
# [7893 rows x 4 columns]

# %%
data.loc[:,["sma_s", "sma_l", "position"]].plot(figsize = (12,8), title = "AAPLE - SMA{} | SMA{}".format(sma_s, sma_l), fontsize = 12, secondary_y = "position")
plt.show()

# %%
data.loc["2016", ["sma_s", "sma_l", "position"]].plot(figsize = (12,8), title = "AAPLE - SMA{} | SMA{}".format(sma_s, sma_l), fontsize = 12, secondary_y = "position")
plt.show()

# %%
data["returnsb&h"] = np.log(data.Close.div(data.Close.shift(1)))

# %%
data["strategy"] = data["returnsb&h"]*data.position.shift(1)

# %%
data.dropna()
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  strategy
# Date
# 1991-05-24    0.409598    0.530960    0.513538         1    0.016483  0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721  0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507  0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209  0.013209
# 1991-05-31    0.419643    0.516027    0.514866         1   -0.013209 -0.013209
# ...                ...         ...         ...       ...         ...       ...
# 2022-09-15  152.369995  159.388000  152.431600         1   -0.019111 -0.019111
# 2022-09-16  150.699997  159.475000  152.309800         1   -0.011021 -0.011021
# 2022-09-19  154.479996  159.623800  152.286600         1    0.024774  0.024774
# 2022-09-20  156.899994  159.864400  152.289900         1    0.015544  0.015544
# 2022-09-21  153.720001  160.021600  152.190700         1   -0.020476 -0.020476
#
# [7892 rows x 6 columns]

# %%
data[["returnsb&h", "strategy"]].sum()
# Out:
# returnsb&h    5.944195
# strategy      1.980044
# dtype: float64

# %%
data[["returnsb&h", "strategy"]].sum().apply(np.exp) #wht 1$ will be
# Out:
# returnsb&h    381.531982
# strategy        7.243064
# dtype: float64

# %%
data[["returnsb&h", "strategy"]].std()*np.sqrt(252)
# Out:
# returnsb&h    0.440612
# strategy      0.440756
# dtype: float64

# %% [markdown]
# # Strategy adjusted with long bias

# %%
data["position2"] = np.where(data["sma_s"] > data["sma_l"], 1, 0)

# %%
data["strategy2"] = data["returnsb&h"]*data.position2.shift(1)

# %%
data.dropna()
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  \
# Date
# 1991-05-24    0.409598    0.530960    0.513538         1    0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209
# 1991-05-31    0.419643    0.516027    0.514866         1   -0.013209
# ...                ...         ...         ...       ...         ...
# 2022-09-15  152.369995  159.388000  152.431600         1   -0.019111
# 2022-09-16  150.699997  159.475000  152.309800         1   -0.011021
# 2022-09-19  154.479996  159.623800  152.286600         1    0.024774
# 2022-09-20  156.899994  159.864400  152.289900         1    0.015544
# 2022-09-21  153.720001  160.021600  152.190700         1   -0.020476
#
#             strategy  position2  strategy2
# Date
# 1991-05-24  0.016483          1   0.016483
# 1991-05-28  0.002721          1   0.002721
# 1991-05-29  0.021507          1   0.021507
# 1991-05-30  0.013209          1   0.013209
# 1991-05-31 -0.013209          1  -0.013209
# ...              ...        ...        ...
# 2022-09-15 -0.019111          1  -0.019111
# 2022-09-16 -0.011021          1  -0.011021
# 2022-09-19  0.024774          1   0.024774
# 2022-09-20  0.015544          1   0.015544
# 2022-09-21 -0.020476          1  -0.020476
#
# [7892 rows x 8 columns]

# %%
data[["returnsb&h", "strategy2"]].sum()
# Out:
# returnsb&h    5.944195
# strategy2     3.962119
# dtype: float64

# %%
data[["returnsb&h", "strategy2"]].sum().apply(np.exp) #wht 1$ will be
# Out:
# returnsb&h    381.531982
# strategy2      52.568626
# dtype: float64

# %%
data[["returnsb&h", "strategy2"]].std()*np.sqrt(252)
# Out:
# returnsb&h    0.440612
# strategy2     0.341025
# dtype: float64

# %%
# strategy 2 is better than strategy 1

# %%
data[["strategy", "strategy2"]].std()*np.sqrt(252)
# Out:
# strategy     0.440756
# strategy2    0.341025
# dtype: float64

# %% [markdown]
# # Creating strategy function

# %%
def test_strategy(stock, start, end, SMA):
    df = yf.download(stock, start = start, end = end)
    data = df.Close.to_frame()
    data["returns"] = np.log(data.Close.div(data.Close.shift(1)))
    data["SMA_S"] = data.Close.rolling(int(SMA[0])).mean()
    data["SMA_L"] = data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace = True)
    
    data["position"] = np.where(data["SMA_S"] > data["SMA_L"], 1 , -1)
    data["strategy"] = data["returns"]*data.position.shift(1)
    data.dropna(inplace = True)
    ret = np.exp(data["strategy"].sum())
    std = data["strategy"].std()*np.sqrt(252)
    
    return ret, std

# %%
test_strategy("MSFT", "2000-01-01", "2020-01-01", (50,200))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (0.417174208955019, 0.29102590916457)

# %%
test_strategy("AAPL", "2000-01-01", "2020-01-01", (50,200))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (16.97303256934803, 0.36700412414290967)

# %%
test_strategy("TSLA", "2000-01-01", "2020-01-01", (50,200))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (1.3908153866370587, 0.49564569049996726)

# %%
test_strategy("SPY", "2000-01-01", "2020-01-01", (50,200))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (4.7880269900097225, 0.18786248569191874)

# %% [markdown]
# # creating a class

# %%
class SMABacktester():
    def __init__(self, symbol, SMA_S, SMA_L,start,end):
        self.symbol = symbol
        self.SMA_S = SMA_S
        self.SMA_L = SMA_L
        self.start = start
        self.end = end
        self.results = None
        self.get_data()
        
    def get_data(self):
        df = yf.download(self.symbol, start = self.start, end = self.end)
        data = df.Close.to_frame()
        data["returns"] = np.log(data.Close.div(data.Close.shift(1)))
        data["SMA_S"] = data.Close.rolling(self.SMA_S).mean()
        data["SMA_L"] = data.Close.rolling(self.SMA_L).mean()
        data.dropna(inplace = True)
        self.data2 = data
        
        return data
    
    def test_results(self):
        data = self.data2.copy()
        data["position"] = np.where(data["SMA_S"] > data["SMA_L"], 1 , -1)
        data["strategy"] = data["returns"]*data.position.shift(1)
        data.dropna(inplace = True)
        data["returnsbh"] = data["returns"].cumsum().apply(np.exp)
        data["returnsstrategy"] = data["strategy"].cumsum().apply(np.exp)
        perf = data["returnsstrategy"].iloc[-1]
        outperf = perf-data["returnsbh"].iloc[-1]
        self.results = data
        
        ret = np.exp(data["strategy"].sum())
        std = data["strategy"].std()*np.sqrt(252)

#         return ret, std
        return round(perf,6), round(outperf,6)
    
    def plot_results(self):
